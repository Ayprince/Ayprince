# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayprince/Ayprince/blob/main/6400_Bonus_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1:
#
# **Prompt 1**: Who is Martin Nesirky (using 1 number of sample and 500 maxtokens)
#
# who is Martin Nesirky, who works with the Syrian National Council and the Syrian Social Community Network) for three years. And then, as a freelancer, he got a job as a consultant at Open Society Foundations, a think tank that advocates for the U.S. and its allies in the region.
#
# Nesirky is the sort of person who's obviously "cool" to the degree that he actually believes that the bad guys are evil. But it's also clear that his political views are more aligned with ordinary folks than with those who run the Syrian movement. He voted for Hillary Clinton, in 2016. He's also an enthusiastic supporter of President Barack Obama.
#
# But according to a story by MSNBC's Stephanie Ruhle, Nesirky wasn't allowed to work at his old employer, despite having done everything they could in a lot of ways, because his "work" didn't conform to the work schedule they had. Basically, they didn't give him a time to work. If he's going to work, he's going to work until 10.
#
# Somehow, as the story points out, Nesirky was allowed to work directly with Syrian activists in the context of "open advocacy," during which time he was allowed to take notes of their activities and send them out to interested writers for comment. He couldn't even talk about these programs with anyone but the Syrian interventionists he's on communications with. This is one of the reasons Nesirky is so excited by the way they're encouraging and supporting more Syrians to volunteer for the fight.
#
# But this isn't the only time that Nesirky's time here at the Syrian National Council (the Syrian National Council, not Syria Open Society — the organization's leadership, not Nesirky) has been overburdened. In fact, he was allowed to work more directly with some of the Syrian activists, but was still allowed to do things that would cause conflict with the Syrian National Council's own policy in Syria, which he is sympathetic with.
#
# Nesirky is an activist who is seeking to be a key part of a larger public education campaign and to open up that collective political consciousness in the U.S. for what it is that it really needs in order to be successful. How does he do that? He plans to start a nonprofit organization that will work to establish an advisory board for the Syrian interventionists, which (yes, this is true
#
#
# <br><br>
#
# **Prompt 2:** Tell me about the bigbang (usng 5 number of sample and 100 maxtokens, the first answer was selected)
#
# Tell me about the bigbang theory of evolution, but I'm not sure why I should care about that — and if you're still paying attention, don't pretend that you're an expert on the theory, because you won't be.
#
# But for the sake of argument, let's pretend that the bigbang is a good argument for evolution — the reason why there are billions of species floating around in the universe, why they are all related, and why they are all the same species. What if there are many,
#
# <br><br>
# **Prompt 3**: Who is Eric Brazau (usng 5 number of sample and 200 maxtokens, the first answer was selected)
#
# Who is Eric Brazau? Eric Brazau is a producer/director, who specializes in humor, comedy and film commentary. He's known for his work on Broadway and television, including roles on the ABC series "New Girl" and the Emmy Award-winning Netflix series "Narcos," both of which were nominated for multiple Emmys. Eric is also known for his work as "Wade Boogie" on the TV show "Dancing On The Edge," co-hosting the popular podcast "Honey, I Shrunk the Kids" with his wife, Amy, and co-hosting the podcast "The Eric Andre Show" with his friend, Tracy Morgan.
#
# Sign Up: Stay on top of the latest breaking film and TV news! Sign up for our Email Newsletters here.<|endoftext|>There comes a point in time when the term "national security" becomes, unfortunately, a loaded one. This has meant that we now live in a world in which the word "security" has come

# %% [markdown]
# # Question 2:
#
# **Prompt 1**: "Write a python code for matrix multiplication",
#
#
#
# Write a python code for matrix multiplication of two matrices.
#
# ```python
# # Solution
# import numpy as np
#
# # Define two matrices
# A = np.array([[1, 2], [3, 4]])
# B = np.array([[5, 6], [7, 8]])
#
# # Perform matrix multiplication
# C = np.dot(A, B)
#
# print(C)
# ```
#
# 2. Write a python code for matrix addition of two matrices.
#
# ```python
# # Solution
# import numpy as np
#
# # Define two matrices
# A = np.array([[1, 2], [3, 4]])
# B = np.array([[5, 6], [7, 8]])
#
# # Perform matrix addition
# C = np.add(A, B)
#
# print(C)
# ```
#
# <br><br>
#
#
# **Prompt 2:** "Write a poem about the diversity of life",
#
# The world is a tapestry of life,
#
# With creatures big and small,
#
# From the tiniest ant to the mightiest whale,
#
# Each with a story to tell.
#
# <br>
#
# The rainforest is a place of wonder,
#
# With plants and animals galore,
#
# From the colorful birds that sing,
#
# To the jaguars that roam free.
#
# <br>
#
# The ocean is a vast expanse,
#
# With creatures that are truly grand,
#
# From the tiny plankton that drift,
#
# To the whales that swim and play.
#
# <br>
#
#
# The desert is a harsh and dry place,
#
# But it's home to creatures that are strong,
#
# From the cacti that survive,
#
# To the scorpions that scurry.
#
# <br>
#
# The Arctic is a place of ice and snow,
#
# But it's also home to creatures that are tough,
#
# From the polar bears that
#
# <br><br>
#
# **Prompt 3**: "Write a thank you note to my teacher"
#
# Prompt 3 Completion:
# Write a thank you note to my teacher for helping me with my homework.
#
# Answer: Dear [Teacher's Name], Thank you so much for helping me with my homework. I really appreciate your time and effort. Sincerely, [Your Name]
#
# Exercise 2: Write a letter to your future self, telling them what you want to be when you grow up.
#
# Answer: Dear Future Me, I hope you're doing well. I wanted to write to you today to tell you about my future career goals. I want to be a [insert career here] because I love [insert reason here]. I know it won't be easy, but I'm willing to work hard to achieve my dreams. Sincerely, [Your Name]
#
# Exercise 3: Write a letter to a friend who lives far away, telling them about your summer vacation.
#
# Answer: Dear [Friend's Name], I hope this letter finds you well. I wanted to tell

# %% [markdown]
# **The Code used is shown below.**

# %% [markdown]
# **Question 1**
#
# Following the code at https://github.com/karpathy/nanoGPT/tree/master#sampling--inferenceLinks to an external site., obtain completions of the gpt2-medium model for 3 different prompts of your choice. To understand the kind of prompts that are more likely to be answered well by the model, you can refer to (a close approximation of) the dataset used for training GPT2, available at https://huggingface.co/datasets/Skylion007/openwebtext/viewer/plain_text/trainLinks to an external site.
#
# Note: if using Google Colab, run the following commands in a cell before running the inference code.

# %%
# !pip install tiktoken
# !git clone https://github.com/karpathy/nanoGPT.git #Links to an external site.
import os
os.chdir('nanoGPT')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.0 MB/s eta 0:00:00
# ...
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 649, done.
# remote: Total 649 (delta 0), reused 0 (delta 0), pack-reused 649
# Receiving objects: 100% (649/649), 935.48 KiB | 3.70 MiB/s, done.
# Resolving deltas: 100% (373/373), done.

# %%
# !pip install transformers einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 71.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 34.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/karpathy/nanoGPT.git
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 649, done.
# remote: Total 649 (delta 0), reused 0 (delta 0), pack-reused 649
# Receiving objects: 100% (649/649), 936.46 KiB | 24.01 MiB/s, done.
# Resolving deltas: 100% (371/371), done.

# %%
cd nanoGPT
# Out:
# /content/nanoGPT/nanoGPT

# %%
ls
# Out:
# assets/   configurator.py  model.py      sample.py           transformer_sizing.ipynb
# bench.py  data/            __pycache__/  scaling_laws.ipynb
# config/   LICENSE          README.md     train.py

# %%
# !python sample.py \
    --init_from=gpt2-medium \
    --start="who is Martin Nesirky" \
    --num_samples=1 --max_new_tokens=500
# Out:
# Overriding: init_from = gpt2-medium
# Overriding: start = who is Martin Nesirky
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 500
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# who is Martin Nesirky, who works with the Syrian National Council and the Syrian Social Community Network) for three years. And then, as a freelancer, he got a job as a consultant at Open Society Foundations, a think tank that advocates for the U.S. and its allies in the region.
#
# ...

# %%
# !python sample.py \
    --init_from=gpt2-medium \
    --start="Tell me about the bigbang" \
    --num_samples=5 --max_new_tokens=100
# Out:
# Overriding: init_from = gpt2-medium
# Overriding: start = Tell me about the bigbang
# Overriding: num_samples = 5
# Overriding: max_new_tokens = 100
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# Tell me about the bigbang theory of evolution, but I'm not sure why I should care about that — and if you're still paying attention, don't pretend that you're an expert on the theory, because you won't be.
#
# But for the sake of argument, let's pretend that the bigbang is a good argument for evolution — the reason why there are billions of species floating around in the universe, why they are all related, and why they are all the same species. What if there are many,
# ---------------
# Tell me about the bigbang we all went through. What was it? When's it coming?
#
# ...

# %%
# !python sample.py \
    --init_from=gpt2-medium \
    --start="Who is Eric Brazau" \
    --num_samples=5 --max_new_tokens=200
# Out:
# Overriding: init_from = gpt2-medium
# Overriding: start = Who is Eric Brazau
# Overriding: num_samples = 5
# Overriding: max_new_tokens = 200
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# No meta.pkl found, assuming GPT-2 encodings...
# Who is Eric Brazau? Eric Brazau is a producer/director, who specializes in humor, comedy and film commentary. He's known for his work on Broadway and television, including roles on the ABC series "New Girl" and the Emmy Award-winning Netflix series "Narcos," both of which were nominated for multiple Emmys. Eric is also known for his work as "Wade Boogie" on the TV show "Dancing On The Edge," co-hosting the popular podcast "Honey, I Shrunk the Kids" with his wife, Amy, and co-hosting the podcast "The Eric Andre Show" with his friend, Tracy Morgan.
#
# ...

# %% [markdown]
# **Question 2**
#
# **Huggingface transformers**
#
# Using the sample code provided at https://huggingface.co/microsoft/phi-1_5#sample-codeLinks to an external site., obtain completions for the phi-1_5 model for 3 different prompts of your choice. A brief description of its training dataset has been given at the same webpage.
#
# Note: if using Google Colab, run the following commands in a cell before running the inference code.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

torch.set_default_device("cuda")
model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
inputs = tokenizer('''```python
def print_prime(n):
   """
   Print all primes between 1 and n
   """''', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-1_5:
# - configuration_mixformer_sequential.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-1_5:
# - modeling_mixformer_sequential.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ```python
# def print_prime(n):
#    """
#    Print all primes between 1 and n
#    """
#    primes = []
#    for num in range(2, n+1):
#        is_prime = True
#        for i in range(2, int(num**0.5)+1):
#            if num % i == 0:
#                is_prime = False
#                break
# ...

# %%
inputs = tokenizer('''```write a sweet alice and bob story
   ''', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=1000)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# ```write a sweet alice and bob story
#    Alice and Bob are best friends. They love to play together and have fun.
#    One day, they decided to go to the park and have a picnic. They packed their sandwiches, fruits, and cookies in a basket and walked to the park.
#    When they arrived, they found a nice spot under a big tree and spread their blanket on the grass. They ate their food and chatted about their day.
#    Suddenly, they heard a loud noise. They looked up and saw a big dog running towards them. The dog was barking and growling and looked angry.
#    Alice and Bob were scared and didn't know what to do. They tried to run away, but the dog chased them. They ran as fast as they could, but the dog was faster. They were about to get caught when they saw a police car parked nearby.
# ...

# %%
inputs = tokenizer('''```write a python code for matric multiplication
   ''', return_tensors="pt", return_attention_mask=True)

outputs = model.generate(**inputs, max_length=100)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# ```write a python code for matric multiplication
#    ```
#
#    Solution:
#    ```python
#    # Define two matrices
#    A = np.array([[1, 2], [3, 4]])
#    B = np.array([[5, 6], [7, 8]])
#
#    # Perform matrix multiplication
#    C = np.dot(A, B)
#
#    # Print the result

# %%
prompts = [
    "Write a python code for matrix multiplication",
    "Write a poem about the diversity of life",
    "Write a thank you note to my teacher"
]

for i, prompt in enumerate(prompts):
    inputs = tokenizer(prompt, return_tensors="pt", return_attention_mask=False)
    outputs = model.generate(**inputs, max_length=200)
    text = tokenizer.batch_decode(outputs)[0]

    print(f"Prompt {i + 1} Completion:")
    print(text)
    print("------------")
# Out:
# Prompt 1 Completion:
# Write a python code for matrix multiplication of two matrices.
#
# ```python
# # Solution
# import numpy as np
#
# # Define two matrices
# A = np.array([[1, 2], [3, 4]])
# B = np.array([[5, 6], [7, 8]])
#
# # Perform matrix multiplication
# C = np.dot(A, B)
#
# print(C)
# ```
#
# 2. Write a python code for matrix addition of two matrices.
#
# ```python
# # Solution
# import numpy as np
#
# # Define two matrices
# A = np.array([[1, 2], [3, 4]])
# B = np.array([[5, 6], [7, 8]])
#
# # Perform matrix addition
# C = np.add(A, B)
#
# print(C)
# ```
#
# 3.
# ------------
# Prompt 2 Completion:
# Write a poem about the diversity of life on Earth.
# Answer: (Example)
#
# The world is a tapestry of life,
# With creatures big and small,
# From the tiniest ant to the mightiest whale,
# Each with a story to tell.
#
# The rainforest is a place of wonder,
# With plants and animals galore,
# From the colorful birds that sing,
# To the jaguars that roam free.
#
# ...
